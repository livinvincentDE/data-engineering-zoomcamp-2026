# %% [markdown]
# <a href="https://colab.research.google.com/github/livinvincentDE/data-engineering-zoomcamp-2026/blob/main/dlt_2026/cohorts/2026/workshops/dlt/dlt_Pipeline_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building a Data Pipeline with dlt
#
# In this notebook, we will build a complete data pipeline from scratch using **dlt**.
#
# Our goal is simple:
#
# → Fetch real data from an API
# → Turn it into clean relational tables
# → Load it into a database
# → Explore and analyze it
#
# We will use the **Open Library API** as our data source and **DuckDB** as our database.
#
# Along the way, you will learn:
#
# - What a dlt source is
# - What a dlt pipeline does
# - How data moves through Extract → Normalize → Load
# - How to inspect and explore the final dataset
#
# By the end, you will understand not just how to run a pipeline, but what happens at each stage.

# %% [markdown]
# ## 📦 Step 0: Install Dependencies

# %%
# install dependencies first
# !pip -q install dlt[duckdb]
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.9/348.9 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.2 MB/s eta 0:00:00

# %% [markdown]
# <p>In this notebook we will use:</p>
#
# <ul>
#   <li><strong>dlt</strong> to extract, normalize, and load data</li>
#   <li><strong>DuckDB</strong> as the destination database (runs locally inside Colab)</li>
# </ul>
#
# <p>
#   DuckDB is great for beginners because it requires no setup and no credentials.
# </p>

# %% [markdown]
# ## 📚 Step 1: Import Libraries

# %% [markdown]
# <p>In this cell we import the libraries we will use throughout the notebook:</p>
#
# <ul>
#   <li><strong>dlt</strong> is the main library for building and running the pipeline</li>
#   <li><strong>rest_api_source</strong> helps us define an API source using a simple configuration</li>
#   <li><strong>islice</strong> (from <code>itertools</code>) is a small Python helper for previewing only a few records</li>
# </ul>

# %%
import dlt
import dlt
from itertools import islice
from dlt.sources.rest_api import rest_api_source

# %% [markdown]
# ## 🔗 Step 2: Define the API Source (Open Library)

# %% [markdown]
# <p>
#   In <strong>dlt</strong>, a <strong>source</strong> is the part of your pipeline that knows how to fetch data from somewhere.
#   In this notebook, our source fetches data from the <strong>Open Library Search API</strong>.
# </p>
#
# <p>
#   We define the source using <code>rest_api_source</code>, which lets us describe an API in a simple
#   Python dictionary instead of writing lots of request code.
# </p>
#
# <p>
#   📖 <strong>Open Library Search API docs:</strong><br>
#   <a href="https://openlibrary.org/dev/docs/api/search" target="_blank">
#     https://openlibrary.org/dev/docs/api/search
#   </a>
# </p>

# %%
def openlibrary_source(query: str = "harry potter"):

    return rest_api_source({
        "client": {
            "base_url": "https://openlibrary.org",
        },
        "resource_defaults": {
            "primary_key": "key",
            "write_disposition": "replace",
        },
        "resources": [
            {
                "name": "books",
                "endpoint": {
                    "path": "search.json",
                    "params": {
                        "q": query,
                        "limit": 100,
                    },
                    "data_selector": "docs",
                    "paginator": {
                        "type": "offset",
                        "limit": 100,
                        "offset_param": "offset",
                        "limit_param": "limit",
                        "total_path": "numFound",
                    },
                },
            },
        ],
    })

# %% [markdown]
# ## 🔧 Step 3: Create the dlt Pipeline

# %%
pipeline = dlt.pipeline(
    pipeline_name="ol_demo",
    destination="duckdb",
    dataset_name="ol_data",
    progress="log" # logs the pipeline run (Optiona)
)

# %% [markdown]
# ## 🔍 Understanding the Pipeline
#
# At this point we have defined two key building blocks:
#
# - **The source** describes where the data comes from and how to fetch it from the API.
# - **The pipeline** describes where the data should go (DuckDB) and keeps track of tables, schemas, and run history.
#
# ---
#
# Instead of running everything at once, we will now run the pipeline in three separate phases so you can clearly see what happens at each stage:
#
# 1. **Extract**: download raw data from the API
# 2. **Normalize**: turn nested JSON into relational tables
# 3. **Load**: write those tables into DuckDB

# %% [markdown]
# ![ETL Diagram](https://github.com/anair123/data-engineering-zoomcamp/blob/workshop/dlt_2026/cohorts/2026/workshops/dlt/images/etl_diagram.png?raw=1)

# %% [markdown]
# Once these steps make sense, we will run the full workflow again using one command:
#
# ```python
# pipeline.run(source)

# %% [markdown]
# ## ⬇️ Step 4: Extract
#
# Now we run the first stage of the pipeline: **Extract**.
#
# Extract means:
#
# - dlt sends requests to the Open Library API
# - the raw JSON responses are downloaded
# - the results are stored in dlt’s local working folder
#
# At this stage, the data is **not** in DuckDB yet. We are just confirming that we successfully pulled data from the API.

# %%
extract_info = pipeline.extract(openlibrary_source())
# Out:
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 222.07 MB (8.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 1.82s | Rate: 0.00/s
# books: 100  | Time: 0.00s | Rate: 4032984.62/s
# Memory usage: 222.35 MB (9.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 3.40s | Rate: 0.00/s
# books: 200  | Time: 1.58s | Rate: 126.67/s
# Memory usage: 222.35 MB (9.50%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 5.24s | Rate: 0.00/s
# books: 300  | Time: 3.43s | Rate: 87.57/s
# Memory usage: 222.35 MB (9.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 6.94s | Rate: 0.00/s
# books: 400  | Time: 5.12s | Rate: 78.08/s
# Memory usage: 222.44 MB (9.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 8.83s | Rate: 0.00/s
# books: 500  | Time: 7.01s | Rate: 71.35/s
# Memory usage: 223.01 MB (9.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 10.17s | Rate: 0.00/s
# books: 600  | Time: 8.36s | Rate: 71.79/s
# Memory usage: 223.28 MB (9.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 11.42s | Rate: 0.00/s
# books: 700  | Time: 9.60s | Rate: 72.92/s
# Memory usage: 223.38 MB (9.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 12.96s | Rate: 0.00/s
# books: 800  | Time: 11.15s | Rate: 71.78/s
# Memory usage: 223.66 MB (9.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 14.42s | Rate: 0.00/s
# books: 900  | Time: 12.60s | Rate: 71.41/s
# Memory usage: 223.95 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 15.97s | Rate: 0.00/s
# books: 1000  | Time: 14.15s | Rate: 70.68/s
# Memory usage: 224.24 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 17.28s | Rate: 0.00/s
# books: 1100  | Time: 15.47s | Rate: 71.12/s
# Memory usage: 224.55 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 19.01s | Rate: 0.00/s
# books: 1200  | Time: 17.19s | Rate: 69.79/s
# Memory usage: 224.83 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 20.58s | Rate: 0.00/s
# books: 1300  | Time: 18.77s | Rate: 69.28/s
# Memory usage: 225.15 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 22.30s | Rate: 0.00/s
# books: 1400  | Time: 20.49s | Rate: 68.34/s
# Memory usage: 225.27 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 24.36s | Rate: 0.00/s
# books: 1500  | Time: 22.55s | Rate: 66.53/s
# Memory usage: 225.53 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 26.55s | Rate: 0.00/s
# books: 1600  | Time: 24.73s | Rate: 64.70/s
# Memory usage: 225.83 MB (10.10%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 28.64s | Rate: 0.00/s
# books: 1700  | Time: 26.82s | Rate: 63.39/s
# Memory usage: 226.13 MB (10.10%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 30.60s | Rate: 0.00/s
# books: 1800  | Time: 28.78s | Rate: 62.54/s
# Memory usage: 226.43 MB (10.10%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 32.44s | Rate: 0.00/s
# books: 1900  | Time: 30.63s | Rate: 62.04/s
# Memory usage: 226.54 MB (10.10%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 34.19s | Rate: 0.00/s
# books: 2000  | Time: 32.37s | Rate: 61.78/s
# Memory usage: 226.84 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 35.61s | Rate: 0.00/s
# books: 2100  | Time: 33.79s | Rate: 62.14/s
# Memory usage: 227.13 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 37.69s | Rate: 0.00/s
# books: 2200  | Time: 35.87s | Rate: 61.33/s
# Memory usage: 227.43 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 39.17s | Rate: 0.00/s
# books: 2300  | Time: 37.35s | Rate: 61.57/s
# Memory usage: 227.73 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 41.49s | Rate: 0.00/s
# books: 2400  | Time: 39.67s | Rate: 60.50/s
# Memory usage: 227.75 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 43.08s | Rate: 0.00/s
# books: 2500  | Time: 41.26s | Rate: 60.59/s
# Memory usage: 227.76 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 44.18s | Rate: 0.00/s
# books: 2600  | Time: 42.36s | Rate: 61.37/s
# Memory usage: 227.76 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 45.90s | Rate: 0.00/s
# books: 2700  | Time: 44.08s | Rate: 61.25/s
# Memory usage: 227.77 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 47.25s | Rate: 0.00/s
# books: 2800  | Time: 45.44s | Rate: 61.62/s
# Memory usage: 227.77 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 49.76s | Rate: 0.00/s
# books: 3000  | Time: 47.95s | Rate: 62.57/s
# Memory usage: 227.77 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 51.41s | Rate: 0.00/s
# books: 3100  | Time: 49.59s | Rate: 62.51/s
# Memory usage: 227.77 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 52.64s | Rate: 0.00/s
# books: 3200  | Time: 50.82s | Rate: 62.97/s
# Memory usage: 227.78 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 54.62s | Rate: 0.00/s
# books: 3300  | Time: 52.81s | Rate: 62.49/s
# Memory usage: 227.78 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 56.08s | Rate: 0.00/s
# books: 3400  | Time: 54.27s | Rate: 62.66/s
# Memory usage: 227.78 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 57.87s | Rate: 0.00/s
# books: 3500  | Time: 56.06s | Rate: 62.44/s
# Memory usage: 227.80 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 59.60s | Rate: 0.00/s
# books: 3600  | Time: 57.78s | Rate: 62.30/s
# Memory usage: 227.90 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 61.69s | Rate: 0.00/s
# books: 3700  | Time: 59.87s | Rate: 61.80/s
# Memory usage: 228.17 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 63.37s | Rate: 0.00/s
# books: 3759  | Time: 61.55s | Rate: 61.07/s
# Memory usage: 228.38 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 1/1 (100.0%) | Time: 63.46s | Rate: 0.02/s
# books: 3759  | Time: 61.65s | Rate: 60.98/s
# Memory usage: 229.01 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 229.01 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# _dlt_pipeline_state: 1  | Time: 0.00s | Rate: 127100.12/s
# Memory usage: 229.01 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 1/1 (100.0%) | Time: 0.02s | Rate: 56.30/s
# _dlt_pipeline_state: 1  | Time: 0.01s | Rate: 74.33/s
# Memory usage: 229.01 MB (10.00%) | CPU usage: 0.00%

# %% [markdown]
# ---
#
# ### What we will print
#
# After extraction, we will print a small summary showing:
#
# - which **resources** were extracted
# - which **tables** will be created later
# - how many rows were extracted per resource
#
# This helps confirm that the pipeline is working before we move on to normalization.

# %%
load_id = extract_info.loads_ids[-1]
m = extract_info.metrics[load_id][0]

print("Resources:", list(m["resource_metrics"].keys()))
print("Tables:", list(m["table_metrics"].keys()))
print("Load ID:", load_id)
print()

for resource, rm in m["resource_metrics"].items():
    print(f"Resource: {resource}")
    print(f"rows extracted: {rm.items_count}")
    print()
# Out:
# Resources: ['books']
# Tables: ['books']
# Load ID: 1772257842.4488602
#
# Resource: books
# rows extracted: 3759

# %% [markdown]
# ### What you should see after Extract
#
# In our case, Extract shows only **one resource and one table**:
#
# - **Resources:** `['books']`
# - **Tables:** `['books']`
#
# That is expected.
#
# The `search` endpoint returns a list of book results, so dlt stores those rows in a single table called `books`. The interesting part comes next, because many fields inside each row are lists or nested objects. Those will turn into additional tables during **Normalize**.
#
# Example output:
#
# - **25 rows extracted** means we pulled 25 search results (books)
#
# ---

# %% [markdown]
# ## 🔄 Step 5: Normalize
#
# Now we run **Normalize**. This is where dlt transforms raw JSON into a clean relational structure.
#
# During normalization, dlt does three key things:
#
# ### 1. Adds Tracking Columns to the Main Table
#
# dlt adds special columns to every table:
# - `_dlt_id`: A unique identifier for each row
# - `_dlt_load_id`: Links each row to the load job that created it
#
# ### 2. Flattens Nested Data into Child Tables
#
# APIs often return nested JSON. For example, a book can have multiple authors (a list), multiple editions, and multiple identifiers.
#
# dlt flattens these nested structures into separate **child tables** with names like:
# - `books__author_name`
# - `books__author_key`
# - `books__language`
#
# Each child table has a `_dlt_parent_id` column that references `_dlt_id` in the parent table. This is how dlt maintains relationships.
#
# ### 3. Creates Metadata Tables
#
# dlt also creates internal tables to track pipeline state:
# - `_dlt_loads`: Tracks load history (when data was loaded, status)
# - `_dlt_pipeline_state`: Stores pipeline state for incremental loading
# - `_dlt_version`: Tracks schema versions
#
# In the next cell, we will print a summary showing which tables were created.

# %%
normalize_info = pipeline.normalize()
# Out:
# ------------------- Normalize rest_api in 1772257842.4488602 -------------------
# Files: 0/2 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 229.30 MB (10.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772257842.4488602 -------------------
# Files: 0/2 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 229.30 MB (10.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772257842.4488602 -------------------
# Files: 10/2 (500.0%) | Time: 0.86s | Rate: 11.63/s
# Items: 23083  | Time: 0.86s | Rate: 26866.25/s
# Memory usage: 235.21 MB (10.00%) | CPU usage: 0.00%

# %%
load_id = normalize_info.loads_ids[-1]
m = normalize_info.metrics[load_id][0]

print("Load ID:", load_id)
print()

print("Tables created/updated:")
for table_name, tm in m["table_metrics"].items():
    # skip dlt internal tables to keep it beginner-friendly
    if table_name.startswith("_dlt"):
        continue
    print(f"  - {table_name}: {tm.items_count} rows")
# Out:
# Load ID: 1772257842.4488602
#
# Tables created/updated:
#   - books: 3759 rows
#   - books__author_key: 4637 rows
#   - books__author_name: 4637 rows
#   - books__ia: 3434 rows
#   - books__ia_collection: 2735 rows
#   - books__language: 3748 rows
#   - books__id_standard_ebooks: 12 rows
#   - books__id_librivox: 64 rows
#   - books__id_project_gutenberg: 56 rows

# %% [markdown]
# ### What happened during Normalize?
#
# After running `pipeline.normalize()`, we now see multiple tables instead of just one.
#
# Tables created/updated:
#
# - `books`
# - `books__author_key`
# - `books__author_name`
# - `books__editions__docs`
# - `books__editions__docs__language`
# - `books__ia`
#
# ---
#
# ### What does this mean?
#
# We started with **N book search results** in the `books` table.
#
# During normalization:
#
# - Each book may have **more than N authors**, so those were split into:
#   - `books__author_name`
#   - `books__author_key`
#
# - Each book may contain **edition information**, which became:
#   - `books__editions__docs`
#
# - Some editions contain **language information**, which became:
#   - `books__editions__docs__language`
#
# - The `ia` field (Internet Archive IDs) is a list, so it became:
#   - `books__ia`
#
# This is the key moment in the pipeline.
#
# The data has been transformed from nested JSON into a **relational structure** with multiple linked tables. This makes it much easier to query and analyze.
#
# ---
#
# ### Schema Visualization
#
# dlt can render the schema as a visual diagram. Run the next cell to see the parent-child table relationships:

# %%
# Display schema
pipeline.default_schema
# Out:
# <dlt.Schema(name='rest_api', version=2, tables=['_dlt_version', '_dlt_loads', 'books', '_dlt_pipeline_state', 'books__author_key', 'books__author_name', 'books__ia', 'books__ia_collection', 'books__language', 'books__id_standard_ebooks', 'books__id_librivox', 'books__id_project_gutenberg'], version_hash='ZJIabaQJ9DAYgsR04wEVeXOgU80roBUfdvrR2YoBEyU=')>

# %% [markdown]
# ## 📤 Step 6: Load
#
# Now we run the final stage of the pipeline: **Load**.
#
# Load means:
#
# - dlt creates tables in DuckDB (if they do not already exist)
# - the normalized rows are inserted into those tables
# - the pipeline records the load in its internal tracking tables

# %%
load_info = pipeline.load()
# Out:
# --------------------- Load rest_api in 1772257842.4488602 ----------------------
# Jobs: 0/10 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 247.24 MB (9.80%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772257842.4488602 ----------------------
# Jobs: 5/10 (50.0%) | Time: 1.13s | Rate: 4.44/s
# Memory usage: 341.69 MB (10.40%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772257842.4488602 ----------------------
# Jobs: 10/10 (100.0%) | Time: 2.02s | Rate: 4.95/s
# Memory usage: 279.96 MB (10.10%) | CPU usage: 0.00%

# %% [markdown]
# After this step, the data is fully stored in the database and ready to query.
#
# At this point:
#
# - The `books` table contains our books
# - The related tables (such as `books__author_name` and `books__editions__docs`) contain the exploded nested data
# - Everything is now queryable using `pipeline.dataset()` or SQL
#
# This is the moment where the data officially moves from “pipeline processing” into a database you can explore.

# %% [markdown]
# ## 🚀 Step 7: Run the Full Pipeline
#
# Now that we have walked through each step individually, we can run the entire workflow using a single command:

# %%
load_info = pipeline.run(openlibrary_source())
# Out:
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 277.69 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 1.86s | Rate: 0.00/s
# books: 100  | Time: 0.00s | Rate: 11650844.44/s
# Memory usage: 277.70 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 2.95s | Rate: 0.00/s
# books: 200  | Time: 1.09s | Rate: 182.67/s
# Memory usage: 277.70 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 4.88s | Rate: 0.00/s
# books: 300  | Time: 3.02s | Rate: 99.23/s
# Memory usage: 277.70 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 6.36s | Rate: 0.00/s
# books: 400  | Time: 4.50s | Rate: 88.86/s
# Memory usage: 277.70 MB (10.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 9.40s | Rate: 0.00/s
# books: 500  | Time: 7.55s | Rate: 66.26/s
# Memory usage: 278.20 MB (10.10%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 10.63s | Rate: 0.00/s
# books: 600  | Time: 8.77s | Rate: 68.38/s
# Memory usage: 278.20 MB (10.10%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 13.21s | Rate: 0.00/s
# books: 700  | Time: 11.35s | Rate: 61.65/s
# Memory usage: 278.21 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 15.66s | Rate: 0.00/s
# books: 900  | Time: 13.80s | Rate: 65.22/s
# Memory usage: 278.21 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 17.21s | Rate: 0.00/s
# books: 1000  | Time: 15.36s | Rate: 65.11/s
# Memory usage: 278.21 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 18.65s | Rate: 0.00/s
# books: 1100  | Time: 16.80s | Rate: 65.49/s
# Memory usage: 278.21 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 19.90s | Rate: 0.00/s
# books: 1200  | Time: 18.04s | Rate: 66.51/s
# Memory usage: 278.21 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 21.36s | Rate: 0.00/s
# books: 1300  | Time: 19.51s | Rate: 66.65/s
# Memory usage: 278.21 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 22.66s | Rate: 0.00/s
# books: 1400  | Time: 20.81s | Rate: 67.28/s
# Memory usage: 278.21 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 24.36s | Rate: 0.00/s
# books: 1500  | Time: 22.50s | Rate: 66.66/s
# Memory usage: 278.52 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 26.04s | Rate: 0.00/s
# books: 1600  | Time: 24.18s | Rate: 66.16/s
# Memory usage: 278.79 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 27.71s | Rate: 0.00/s
# books: 1700  | Time: 25.85s | Rate: 65.76/s
# Memory usage: 279.06 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 29.74s | Rate: 0.00/s
# books: 1800  | Time: 27.88s | Rate: 64.56/s
# Memory usage: 279.33 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 32.11s | Rate: 0.00/s
# books: 1900  | Time: 30.25s | Rate: 62.81/s
# Memory usage: 279.61 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 34.11s | Rate: 0.00/s
# books: 2000  | Time: 32.25s | Rate: 62.01/s
# Memory usage: 279.75 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 36.36s | Rate: 0.00/s
# books: 2100  | Time: 34.51s | Rate: 60.86/s
# Memory usage: 279.99 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 38.11s | Rate: 0.00/s
# books: 2200  | Time: 36.25s | Rate: 60.69/s
# Memory usage: 280.26 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 40.15s | Rate: 0.00/s
# books: 2300  | Time: 38.30s | Rate: 60.06/s
# Memory usage: 280.54 MB (9.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 42.12s | Rate: 0.00/s
# books: 2400  | Time: 40.26s | Rate: 59.61/s
# Memory usage: 280.84 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 44.32s | Rate: 0.00/s
# books: 2500  | Time: 42.46s | Rate: 58.88/s
# Memory usage: 280.95 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 46.13s | Rate: 0.00/s
# books: 2600  | Time: 44.27s | Rate: 58.73/s
# Memory usage: 281.22 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 48.20s | Rate: 0.00/s
# books: 2700  | Time: 46.34s | Rate: 58.26/s
# Memory usage: 281.52 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 50.16s | Rate: 0.00/s
# books: 2800  | Time: 48.30s | Rate: 57.97/s
# Memory usage: 281.82 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 52.02s | Rate: 0.00/s
# books: 2900  | Time: 50.16s | Rate: 57.81/s
# Memory usage: 282.11 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 53.54s | Rate: 0.00/s
# books: 3000  | Time: 51.68s | Rate: 58.04/s
# Memory usage: 282.40 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 55.12s | Rate: 0.00/s
# books: 3100  | Time: 53.27s | Rate: 58.20/s
# Memory usage: 282.70 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 57.24s | Rate: 0.00/s
# books: 3200  | Time: 55.38s | Rate: 57.78/s
# Memory usage: 282.85 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 58.65s | Rate: 0.00/s
# books: 3300  | Time: 56.79s | Rate: 58.11/s
# Memory usage: 283.13 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 61.71s | Rate: 0.00/s
# books: 3400  | Time: 59.86s | Rate: 56.80/s
# Memory usage: 283.31 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 64.22s | Rate: 0.00/s
# books: 3500  | Time: 62.37s | Rate: 56.12/s
# Memory usage: 283.31 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 66.00s | Rate: 0.00/s
# books: 3600  | Time: 64.15s | Rate: 56.12/s
# Memory usage: 283.31 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 68.09s | Rate: 0.00/s
# books: 3700  | Time: 66.23s | Rate: 55.86/s
# Memory usage: 283.39 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 70.25s | Rate: 0.00/s
# books: 3759  | Time: 68.40s | Rate: 54.96/s
# Memory usage: 283.39 MB (9.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 1/1 (100.0%) | Time: 70.36s | Rate: 0.01/s
# books: 3759  | Time: 68.50s | Rate: 54.87/s
# Memory usage: 286.49 MB (9.90%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772257910.4079497 -------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 286.54 MB (9.90%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772257910.4079497 -------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 286.54 MB (9.90%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772257910.4079497 -------------------
# Files: 9/1 (900.0%) | Time: 0.95s | Rate: 9.44/s
# Items: 23082  | Time: 0.95s | Rate: 24225.69/s
# Memory usage: 291.65 MB (9.90%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772257910.4079497 ----------------------
# Jobs: 0/9 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 291.65 MB (9.90%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772257910.4079497 ----------------------
# Jobs: 6/9 (66.7%) | Time: 1.00s | Rate: 5.98/s
# Memory usage: 323.46 MB (10.20%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772257910.4079497 ----------------------
# Jobs: 9/9 (100.0%) | Time: 1.64s | Rate: 5.48/s
# Memory usage: 292.90 MB (10.00%) | CPU usage: 0.00%

# %% [markdown]
# <h3>What does <code>pipeline.run()</code> do?</h3>
#
# <p>
#   <code>pipeline.run()</code> simply combines the three steps we already executed manually:
# </p>
#
# <ol>
#   <li><strong>Extract</strong> – fetch data from the Open Library API</li>
#   <li><strong>Normalize</strong> – convert nested JSON into relational tables</li>
#   <li><strong>Load</strong> – write those tables into DuckDB</li>
# </ol>
#
# <p>In other words, this:</p>
#
# <pre><code>pipeline.run(source)</code></pre>
#
# <p>is equivalent to:</p>
#
# <pre><code>pipeline.extract(source)
# pipeline.normalize()
# pipeline.load()</code></pre>
#
# <p>
#   There is no hidden magic. It just runs the full ELT process in order.
# </p>

# %% [markdown]
# ## 🔎 Step 8: Inspect the Loaded Data
#
# Now that the data is loaded into DuckDB, we can inspect it using `pipeline.dataset()`.
#
# This gives us a convenient Python interface for exploring the tables that dlt created, without writing SQL.
#
# ---
#
# ### List available tables
#
# First, let’s see what tables exist in the dataset:

# %%
ds = pipeline.dataset()

# %%
ds.tables
# Out:
# ['books',
#  'books__author_key',
#  'books__author_name',
#  'books__ia',
#  'books__ia_collection',
#  'books__language',
#  'books__id_standard_ebooks',
#  'books__id_librivox',
#  'books__id_project_gutenberg',
#  '_dlt_version',
#  '_dlt_loads',
#  '_dlt_pipeline_state']

# %%
df = ds.books.df()      # main table
df.head(3)
# Out:
#   cover_edition_key   cover_i   ebook_access  edition_count  \
# 0       OL61027601M  15155833     borrowable            397
# 1       OL26378158M  15158660  printdisabled            144
# 2       OL26234270M  10580435     borrowable            279
#
#    first_publish_year  has_fulltext              key lending_edition_s  \
# 0                1997          True  /works/OL82563W       OL38565767M
# 1                2007          True  /works/OL82586W              None
# 2                1999          True  /works/OL82536W       OL48101764M
#
#             lending_identifier_s  public_scan_b  \
# 0  harrypotterylapi0000rowl_q5r6          False
# 1                           None          False
# 2                 bdrc-W8LS66814          False
#
#                                       title        _dlt_load_id  \
# 0  Harry Potter and the Philosopher's Stone  1772257910.4079497
# 1      Harry Potter and the Deathly Hallows  1772257910.4079497
# 2  Harry Potter and the Prisoner of Azkaban  1772257910.4079497
#
#           _dlt_id subtitle
# 0  Ob1IQXIPtJfRzA     None
# 1  gxKhYzXek3zBYw     None
# 2  3dHbt7SZnvAZBw     None

# %% [markdown]
# ## 💡 Conclusion
#
# ### What dlt handled for us
#
# ✔ API requests
# ✔ JSON normalization
# ✔ Table creation
# ✔ Database loading
# ✔ Simple dataset inspection
#
# ---
#
# ### But there are still friction points
#
# • Getting the REST API config exactly right
# • Remembering paginator syntax
# • Remembering how to inspect tables
# • Debugging schema or pagination issues
# • Writing Python or SQL to get insights
#
# It works... but it still takes effort.
#
# ---
#
# ## 🚀 Next Up: LLM-Powered Workflows
#
# dlt now integrates LLMs directly into the workflow to make:
#
# • Pipeline runs easier
# • Debugging faster
# • Schema inspection simpler
# • Data analysis more natural
#
# Instead of writing glue code, you can use natural language.
#
# In the workshop, we will see what that looks like.
